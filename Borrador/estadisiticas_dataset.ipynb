# %%
# %matplotlib inline
# %matplotlib notebook
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
with h5py.File('./train_model/images/data_mapa.h5', 'r') as hf:
    print(hf.keys())
    imagen = hf["images"].value
    cuentas=hf["counts"].value
    densidad = hf["density"].value
# Out:
# <KeysViewHDF5 ['counts', 'density', 'density_model', 'images']>
# /home/daniel/anaconda3/lib/python3.6/site-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)

# %%
unique, counts = np.unique(cuentas, return_counts=True)
# print(np.asarray((unique, counts)).T)

# %%
n, bins, patches = plt.hist(cuentas, unique, facecolor='blue', alpha=0.5)

# %%
plt.figure()
plt.imshow(imagen[0])
plt.imshow(densidad[0],alpha =0.3)

# %%
unique, counts = np.unique(densidad[0], return_counts=True)
# Out:
# [[0.00000000e+00 9.17500000e+03]
#  [7.82685456e-05 1.20000000e+01]
#  [1.61155229e-04 2.40000000e+01]
#  [2.29349331e-04 4.00000000e+00]
#  [2.96924874e-04 2.20000000e+01]
#  [3.31819203e-04 1.20000000e+01]
#  [3.99735000e-04 4.00000000e+00]
#  [4.72231099e-04 4.00000000e+00]
#  [4.89546394e-04 2.20000000e+01]
#  [6.11369440e-04 2.20000000e+01]
#  [6.23436121e-04 4.00000000e+00]
#  [7.22247642e-04 2.40000000e+01]
#  [8.23055860e-04 4.00000000e+00]
#  [8.70075193e-04 8.00000000e+00]
#  [9.53506096e-04 2.40000000e+01]
#  [1.00797776e-03 2.20000000e+01]
#  [1.08659244e-03 4.00000000e+00]
#  [1.12643442e-03 3.40000000e+01]
#  [1.19078509e-03 1.20000000e+01]
#  [1.21428771e-03 4.00000000e+00]
#  [1.28365727e-03 4.00000000e+00]
#  [1.43451139e-03 4.00000000e+00]
#  [1.48711051e-03 2.40000000e+01]
#  [1.51646184e-03 4.00000000e+00]
#  [1.79148803e-03 4.00000000e+00]
#  [1.85717631e-03 2.00000000e+01]
#  [1.96327269e-03 2.40000000e+01]
#  [2.11639307e-03 4.00000000e+00]
# ...

# %%
unique, counts = np.unique(densidad, return_counts=True)
# print(np.asarray((unique, counts)).T)
n, bins, patches = plt.hist(densidad, unique, facecolor='blue', alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-547427565b1d> in <module>
#       1 unique, counts = np.unique(densidad, return_counts=True)
#       2 # print(np.asarray((unique, counts)).T)
# ----> 3 n, bins, patches = plt.hist(densidad, unique, facecolor='blue', alpha=0.5)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
total = []
for element in densidad:
    total.append(element.ravel())
total = np.array(total)

# %%
total = total.ravel()
total.shape
# Out:
# (55650000,)

# %%
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
unique, counts = np.unique(total, return_counts=True)
print(np.asarray((unique, counts)).T)
plt.hist(total, normed=True, bins=40)
plt.xlim(0,0.002)
plt.show()
# Out:
# [[0.00000000e+00 4.93616160e+07]
#  [7.82685456e-05 1.11047000e+05]
#  [1.14698618e-04 2.20000000e+01]
#  ...
#  [6.48461953e-02 4.00000000e+00]
#  [6.85507134e-02 4.00000000e+00]
#  [7.24668577e-02 1.00000000e+00]]
